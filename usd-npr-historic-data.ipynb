# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.exchange-rates.org/exchange-rate-history/usd-npr-2015"
request = requests.get(url)
soup = BeautifulSoup(request.content, 'lxml')
table = soup.find_all('table')
table
# Out:
# [<table class="history-rate-summary">
#  <tr>
#  <td><span class="strong-green">Highest:</span></td>
#  <td>107.91 NPR on December 15, 2015</td>
#  </tr>
#  <tr>
#  <td><span class="strong-blue">Average:</span></td>
#  <td>102.49 NPR over this period</td>
#  </tr>
#  <tr>
#  <td><span class="strong-red">Lowest:</span></td>
#  <td>97.969 NPR on April 6, 2015</td>
#  </tr>
#  </table>,
#  <table border="0" cellpadding="0" cellspacing="0" class="history-rates-data">
#  <tbody>
#  <tr class="month-row">
#  <th class="month-header" colspan="3">January 2015</th>
#  </tr>
#  <tr>
#  <th class="ltr-bidi-fix">Date</th>
#  <th class="ltr-bidi-fix">US Dollar to Nepalese Rupee</th>
#  </tr>
#  <tr>
#  <td>
#  <a class="w" href="/exchange-rate-history/usd-npr-2015-01-01">January 1, 2015</a>
#  <a class="n" href="/exchange-rate-history/usd-npr-2015-01-01">2015-1-1</a>
#  </td>
#  <td>
#  <span class="w"><span class="nowrap">1 USD =</span> <span class="nowrap">101.00 NPR</span></span>
# ...
